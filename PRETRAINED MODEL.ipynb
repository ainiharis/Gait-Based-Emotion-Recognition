# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# start running the code

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications import Xception, InceptionV3, VGG16, ResNet50
from tensorflow.keras.applications import MobileNetV2, EfficientNetB0, DenseNet121
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score
import os # Importing the os module

# Specifying train, valid and test directory paths
# Use os.path.join to create correct paths
train_path = os.path.join('/content/drive/MyDrive/FYP/dataset', 'train')
valid_path = os.path.join('/content/drive/MyDrive/FYP/dataset', 'validation')
test_path = os.path.join('/content/drive/MyDrive/FYP/dataset', 'test')

# Rescaling the image
train_batches = ImageDataGenerator(rescale=1.0 / 255.0)
valid_batches = ImageDataGenerator(rescale=1.0 / 255.0)
test_batches = ImageDataGenerator(rescale=1.0 / 255.0)

# %%
# Train data generator
train_gen = train_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    classes=['angry', 'happy', 'neutral', 'sad'],
    batch_size=32
)

# Valid data generator
valid_gen = valid_batches.flow_from_directory(
    directory=valid_path,
    target_size=(224, 224),
    classes=['angry', 'happy', 'neutral', 'sad'],
    batch_size=32
)

# Test data generator
test_gen = test_batches.flow_from_directory(
    directory=test_path,
    target_size=(224, 224),
    classes=['angry', 'happy', 'neutral', 'sad'],
    batch_size=32,
    shuffle=False
)
# Out:
# Found 1764 images belonging to 4 classes.
# Found 376 images belonging to 4 classes.
# Found 380 images belonging to 4 classes.

# %% [markdown]
# INITIALIZING MODELS

# %%
# Initializing models
model_vgg = VGG16(include_top=False, input_shape=(224, 224, 3))
model_xception = Xception(include_top=False, input_shape=(224, 224, 3))
model_inception = InceptionV3(include_top=False, input_shape=(224, 224, 3))
model_resnet = ResNet50(include_top=False, input_shape=(224, 224, 3))
model_mobilenet = MobileNetV2(include_top=False, input_shape=(224, 224, 3))
model_efficientnet = EfficientNetB0(include_top=False, input_shape=(224, 224, 3))
model_densenet = DenseNet121(include_top=False, input_shape=(224, 224, 3))

# %%
# Freezing the layers so that they cannot be trained again
names = [model_vgg, model_xception, model_inception, model_resnet, model_mobilenet, model_efficientnet, model_densenet]
for model in names:
    # Iterating all the layers in the pre-trained model
    for layer in model.layers:
        # Making trainable layers set to False
        layer.trainable = False

# %%
# Fine-tuning the pre-trained models
output_classes = len(train_gen.class_indices)

# Custom VGG16 model
custom_vgg_model = Sequential([
    model_vgg,
    GlobalAveragePooling2D(),  # Faster than Flatten()
    Dense(256, activation='relu'),
    Dropout(0.3),  # Reduce dropout for speed
    Dense(output_classes, activation='softmax')
])

# Custom Xception model
custom_xc_model = Sequential([
    model_xception,
    GlobalAveragePooling2D(),
    Dense(output_classes, activation='softmax')
])

# Custom Inception model
custom_inc_model = Sequential([
    model_inception,
    GlobalAveragePooling2D(),
    Dense(output_classes, activation='softmax')
])

# Custom ResNet model
custom_resnet_model = Sequential([
    model_resnet,
    GlobalAveragePooling2D(),
    Dense(output_classes, activation='softmax')
])

# Custom MobileNetV2 model
custom_mobilenet_model = Sequential([
    model_mobilenet,
    GlobalAveragePooling2D(),
    Dense(output_classes, activation='softmax')
])

# Custom EfficientNetB0 model
custom_efficientnet_model = Sequential([
    model_efficientnet,
    GlobalAveragePooling2D(),
    Dense(output_classes, activation='softmax')
])

# Custom DenseNet121 model
custom_densenet_model = Sequential([
    model_densenet,
    GlobalAveragePooling2D(),
    Dense(output_classes, activation='softmax')
])

# %%
# Compiling the model
models = [custom_vgg_model, custom_xc_model, custom_inc_model, custom_resnet_model]

for model in models:
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

# %%
# Compiling the models
models = [custom_mobilenet_model, custom_efficientnet_model, custom_densenet_model]

for model in models:
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

# %% [markdown]
# VGG16

# %%
import time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_histories = []

print(">>> Training VGG16 model:")
start_time = time.time()

result_vgg = custom_vgg_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

end_time = time.time()
elapsed_time = end_time - start_time
epochs_completed = len(result_vgg.history['loss'])

model_histories.append((result_vgg.history, "VGG16"))

print(f">>> Training completed in {elapsed_time:.2f} seconds.")
print(f">>> Epochs completed: {epochs_completed}")

print(">>> Evaluating VGG16 on the Test data:")
test_pred_vgg = custom_vgg_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy_vgg = accuracy_score(np.argmax(test_pred_vgg, axis=1), test_labels)
print(f">>> Test Accuracy for VGG16: {test_accuracy_vgg * 100:.2f}%.")
# Out:
# >>> Training VGG16 model:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 238ms/step - accuracy: 0.9840 - loss: 0.1033 - val_accuracy: 0.9628 - val_loss: 0.1373
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 224ms/step - accuracy: 0.9821 - loss: 0.1040 - val_accuracy: 0.9521 - val_loss: 0.1564
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.9663 - loss: 0.1311 - val_accuracy: 0.9734 - val_loss: 0.1249
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.9809 - loss: 0.0936 - val_accuracy: 0.9441 - val_loss: 0.1752
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.9716 - loss: 0.1078 - val_accuracy: 0.9681 - val_loss: 0.1225
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 209ms/step - accuracy: 0.9930 - loss: 0.0718 - val_accuracy: 0.9814 - val_loss: 0.1121
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.9904 - loss: 0.0879 - val_accuracy: 0.9681 - val_loss: 0.1309
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.9737 - loss: 0.1009 - val_accuracy: 0.9814 - val_loss: 0.1098
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 216ms/step - accuracy: 0.9872 - loss: 0.0823 - val_accuracy: 0.9840 - val_loss: 0.1001
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.9788 - loss: 0.0898 - val_accuracy: 0.9867 - val_loss: 0.0945
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 205ms/step - accuracy: 0.9929 - loss: 0.0754 - val_accuracy: 0.9734 - val_loss: 0.1090
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 207ms/step - accuracy: 0.9936 - loss: 0.0630 - val_accuracy: 0.9761 - val_loss: 0.1151
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 221ms/step - accuracy: 0.9865 - loss: 0.0785 - val_accuracy: 0.9867 - val_loss: 0.0944
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 211ms/step - accuracy: 0.9918 - loss: 0.0669 - val_accuracy: 0.9681 - val_loss: 0.1219
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 211ms/step - accuracy: 0.9797 - loss: 0.0898 - val_accuracy: 0.9787 - val_loss: 0.0977
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 210ms/step - accuracy: 0.9907 - loss: 0.0651 - val_accuracy: 0.9468 - val_loss: 0.1687
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.9828 - loss: 0.0813 - val_accuracy: 0.9681 - val_loss: 0.1190
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 208ms/step - accuracy: 0.9839 - loss: 0.0783 - val_accuracy: 0.9628 - val_loss: 0.1183
# >>> Training completed in 260.43 seconds.
# >>> Epochs completed: 18
# >>> Evaluating VGG16 on the Test data:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 168s 15s/step
# >>> Test Accuracy for VGG16: 97.37%.

# %% [markdown]
# Xception

# %%
import time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

print(">>> Training Xception model:")
start_time = time.time()

result_xc = custom_xc_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

end_time = time.time()
elapsed_time = end_time - start_time
epochs_completed = len(result_xc.history['loss'])

model_histories.append((result_xc.history, "Xception"))

print(f">>> Training completed in {elapsed_time:.2f} seconds.")
print(f">>> Epochs completed: {epochs_completed}")

print(">>> Evaluating Xception on the Test data:")
test_pred_xc = custom_xc_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy_xc = accuracy_score(np.argmax(test_pred_xc, axis=1), test_labels)
print(f">>> Test Accuracy for Xception: {test_accuracy_xc * 100:.2f}%.")
# Out:
# >>> Training Xception model:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 36s 412ms/step - accuracy: 0.2821 - loss: 1.4581 - val_accuracy: 0.3537 - val_loss: 1.2980
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.4634 - loss: 1.2433 - val_accuracy: 0.4521 - val_loss: 1.2147
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.5166 - loss: 1.1512 - val_accuracy: 0.5878 - val_loss: 1.0896
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.6056 - loss: 1.0649 - val_accuracy: 0.6543 - val_loss: 1.0392
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.6797 - loss: 0.9911 - val_accuracy: 0.6888 - val_loss: 0.9721
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.7584 - loss: 0.9079 - val_accuracy: 0.6862 - val_loss: 0.9350
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7545 - loss: 0.8586 - val_accuracy: 0.7101 - val_loss: 0.8903
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - accuracy: 0.7812 - loss: 0.8100 - val_accuracy: 0.7394 - val_loss: 0.8360
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.8081 - loss: 0.7526 - val_accuracy: 0.7500 - val_loss: 0.8199
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.8223 - loss: 0.7267 - val_accuracy: 0.7527 - val_loss: 0.7721
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.8293 - loss: 0.6892 - val_accuracy: 0.7447 - val_loss: 0.7709
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.8448 - loss: 0.6580 - val_accuracy: 0.8138 - val_loss: 0.6929
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.8700 - loss: 0.6250 - val_accuracy: 0.8085 - val_loss: 0.6684
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.8734 - loss: 0.5956 - val_accuracy: 0.7819 - val_loss: 0.6867
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.8839 - loss: 0.5802 - val_accuracy: 0.8112 - val_loss: 0.6486
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.8790 - loss: 0.5524 - val_accuracy: 0.8351 - val_loss: 0.6128
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9079 - loss: 0.5265 - val_accuracy: 0.8032 - val_loss: 0.6195
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9068 - loss: 0.4982 - val_accuracy: 0.8644 - val_loss: 0.5628
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9058 - loss: 0.4910 - val_accuracy: 0.8457 - val_loss: 0.5616
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.9105 - loss: 0.4719 - val_accuracy: 0.8271 - val_loss: 0.5613
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9174 - loss: 0.4533 - val_accuracy: 0.8511 - val_loss: 0.5320
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 198ms/step - accuracy: 0.9243 - loss: 0.4375 - val_accuracy: 0.8484 - val_loss: 0.5211
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.9323 - loss: 0.4198 - val_accuracy: 0.8617 - val_loss: 0.5139
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9412 - loss: 0.4113 - val_accuracy: 0.8697 - val_loss: 0.4922
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9491 - loss: 0.3851 - val_accuracy: 0.8830 - val_loss: 0.4711
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - accuracy: 0.9597 - loss: 0.3767 - val_accuracy: 0.8803 - val_loss: 0.4666
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.9576 - loss: 0.3676 - val_accuracy: 0.8590 - val_loss: 0.4711
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9554 - loss: 0.3581 - val_accuracy: 0.8963 - val_loss: 0.4384
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 199ms/step - accuracy: 0.9582 - loss: 0.3411 - val_accuracy: 0.8989 - val_loss: 0.4290
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9571 - loss: 0.3209 - val_accuracy: 0.9069 - val_loss: 0.4143
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.9603 - loss: 0.3199 - val_accuracy: 0.8803 - val_loss: 0.4352
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9659 - loss: 0.3140 - val_accuracy: 0.9149 - val_loss: 0.3984
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9670 - loss: 0.2971 - val_accuracy: 0.8697 - val_loss: 0.4259
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9651 - loss: 0.3056 - val_accuracy: 0.9096 - val_loss: 0.3860
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9749 - loss: 0.2819 - val_accuracy: 0.8936 - val_loss: 0.4085
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9582 - loss: 0.2949 - val_accuracy: 0.9122 - val_loss: 0.3734
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9726 - loss: 0.2673 - val_accuracy: 0.9229 - val_loss: 0.3538
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - accuracy: 0.9813 - loss: 0.2510 - val_accuracy: 0.9149 - val_loss: 0.3470
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 193ms/step - accuracy: 0.9819 - loss: 0.2516 - val_accuracy: 0.9255 - val_loss: 0.3480
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9819 - loss: 0.2396 - val_accuracy: 0.9282 - val_loss: 0.3400
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.9757 - loss: 0.2359 - val_accuracy: 0.9388 - val_loss: 0.3302
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 193ms/step - accuracy: 0.9781 - loss: 0.2426 - val_accuracy: 0.9388 - val_loss: 0.3287
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9790 - loss: 0.2212 - val_accuracy: 0.9388 - val_loss: 0.3303
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.9796 - loss: 0.2213 - val_accuracy: 0.9202 - val_loss: 0.3212
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9866 - loss: 0.2112 - val_accuracy: 0.9229 - val_loss: 0.3166
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.9891 - loss: 0.2024 - val_accuracy: 0.9362 - val_loss: 0.3019
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.9862 - loss: 0.2046 - val_accuracy: 0.9495 - val_loss: 0.2927
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.9875 - loss: 0.1966 - val_accuracy: 0.9362 - val_loss: 0.3088
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 188ms/step - accuracy: 0.9880 - loss: 0.1801 - val_accuracy: 0.9388 - val_loss: 0.2922
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9896 - loss: 0.1820 - val_accuracy: 0.9468 - val_loss: 0.2899
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 202ms/step - accuracy: 0.9814 - loss: 0.1904 - val_accuracy: 0.9495 - val_loss: 0.2779
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9869 - loss: 0.1782 - val_accuracy: 0.9415 - val_loss: 0.2760
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.9926 - loss: 0.1687 - val_accuracy: 0.9441 - val_loss: 0.2782
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.9894 - loss: 0.1724 - val_accuracy: 0.9441 - val_loss: 0.2679
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9876 - loss: 0.1686 - val_accuracy: 0.9441 - val_loss: 0.2582
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - accuracy: 0.9878 - loss: 0.1608 - val_accuracy: 0.9468 - val_loss: 0.2555
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9937 - loss: 0.1558 - val_accuracy: 0.9495 - val_loss: 0.2536
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9898 - loss: 0.1632 - val_accuracy: 0.9468 - val_loss: 0.2470
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.9901 - loss: 0.1516 - val_accuracy: 0.9574 - val_loss: 0.2517
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9959 - loss: 0.1478 - val_accuracy: 0.9521 - val_loss: 0.2438
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9965 - loss: 0.1445 - val_accuracy: 0.9521 - val_loss: 0.2374
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - accuracy: 0.9961 - loss: 0.1358 - val_accuracy: 0.9548 - val_loss: 0.2360
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9939 - loss: 0.1404 - val_accuracy: 0.9574 - val_loss: 0.2339
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9890 - loss: 0.1379 - val_accuracy: 0.9441 - val_loss: 0.2389
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - accuracy: 0.9942 - loss: 0.1322 - val_accuracy: 0.9468 - val_loss: 0.2401
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9937 - loss: 0.1296 - val_accuracy: 0.9574 - val_loss: 0.2191
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9954 - loss: 0.1270 - val_accuracy: 0.9468 - val_loss: 0.2238
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9919 - loss: 0.1254 - val_accuracy: 0.9628 - val_loss: 0.2247
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - accuracy: 0.9970 - loss: 0.1164 - val_accuracy: 0.9628 - val_loss: 0.2122
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9953 - loss: 0.1140 - val_accuracy: 0.9654 - val_loss: 0.2147
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9939 - loss: 0.1161 - val_accuracy: 0.9601 - val_loss: 0.2077
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9970 - loss: 0.1060 - val_accuracy: 0.9574 - val_loss: 0.2152
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 182ms/step - accuracy: 0.9936 - loss: 0.1122 - val_accuracy: 0.9681 - val_loss: 0.2039
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9976 - loss: 0.1018 - val_accuracy: 0.9548 - val_loss: 0.2194
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.9936 - loss: 0.1127 - val_accuracy: 0.9548 - val_loss: 0.1994
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9950 - loss: 0.1015 - val_accuracy: 0.9654 - val_loss: 0.1954
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9987 - loss: 0.1013 - val_accuracy: 0.9654 - val_loss: 0.1944
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9997 - loss: 0.0981 - val_accuracy: 0.9628 - val_loss: 0.1883
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9974 - loss: 0.0932 - val_accuracy: 0.9601 - val_loss: 0.1895
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9981 - loss: 0.0920 - val_accuracy: 0.9654 - val_loss: 0.1858
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.9991 - loss: 0.0888 - val_accuracy: 0.9628 - val_loss: 0.1823
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9992 - loss: 0.0912 - val_accuracy: 0.9601 - val_loss: 0.1850
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9984 - loss: 0.0904 - val_accuracy: 0.9628 - val_loss: 0.1850
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.9983 - loss: 0.0879 - val_accuracy: 0.9681 - val_loss: 0.1830
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9995 - loss: 0.0856 - val_accuracy: 0.9654 - val_loss: 0.1762
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9990 - loss: 0.0773 - val_accuracy: 0.9654 - val_loss: 0.1777
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.9976 - loss: 0.0836 - val_accuracy: 0.9628 - val_loss: 0.1795
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9977 - loss: 0.0813 - val_accuracy: 0.9601 - val_loss: 0.1762
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 200ms/step - accuracy: 0.9968 - loss: 0.0778 - val_accuracy: 0.9601 - val_loss: 0.1699
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9994 - loss: 0.0743 - val_accuracy: 0.9681 - val_loss: 0.1684
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9989 - loss: 0.0711 - val_accuracy: 0.9654 - val_loss: 0.1686
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9999 - loss: 0.0716 - val_accuracy: 0.9681 - val_loss: 0.1656
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9996 - loss: 0.0704 - val_accuracy: 0.9654 - val_loss: 0.1657
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9994 - loss: 0.0742 - val_accuracy: 0.9654 - val_loss: 0.1693
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9979 - loss: 0.0734 - val_accuracy: 0.9707 - val_loss: 0.1560
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9994 - loss: 0.0686 - val_accuracy: 0.9654 - val_loss: 0.1576
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 0.9998 - loss: 0.0631 - val_accuracy: 0.9681 - val_loss: 0.1796
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9996 - loss: 0.0662 - val_accuracy: 0.9734 - val_loss: 0.1536
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 1.0000 - loss: 0.0648 - val_accuracy: 0.9707 - val_loss: 0.1527
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 1.0000 - loss: 0.0630 - val_accuracy: 0.9654 - val_loss: 0.1685
# >>> Training completed in 1206.12 seconds.
# >>> Epochs completed: 100
# >>> Evaluating Xception on the Test data:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 13s 830ms/step
# >>> Test Accuracy for Xception: 97.37%.

# %% [markdown]
# InceptionV3

# %%
import time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

print(">>> Training InceptionV3 model:")
start_time = time.time()

result_inc = custom_inc_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

end_time = time.time()
elapsed_time = end_time - start_time
epochs_completed = len(result_inc.history['loss'])

model_histories.append((result_inc.history, "InceptionV3"))

print(f">>> Training completed in {elapsed_time:.2f} seconds.")
print(f">>> Epochs completed: {epochs_completed}")

print(">>> Evaluating InceptionV3 on the Test data:")
test_pred_inc = custom_inc_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy_inc = accuracy_score(np.argmax(test_pred_inc, axis=1), test_labels)
print(f">>> Test Accuracy for InceptionV3: {test_accuracy_inc * 100:.2f}%.")
# Out:
# >>> Training InceptionV3 model:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 60s 792ms/step - accuracy: 0.2675 - loss: 1.6553 - val_accuracy: 0.3245 - val_loss: 1.3207
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.4810 - loss: 1.1809 - val_accuracy: 0.5532 - val_loss: 1.1235
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.6125 - loss: 1.0106 - val_accuracy: 0.6011 - val_loss: 1.0131
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7050 - loss: 0.8818 - val_accuracy: 0.6064 - val_loss: 0.9639
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.7473 - loss: 0.7764 - val_accuracy: 0.6729 - val_loss: 0.8455
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.7990 - loss: 0.6987 - val_accuracy: 0.7766 - val_loss: 0.7606
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.8539 - loss: 0.6192 - val_accuracy: 0.7926 - val_loss: 0.7095
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.8813 - loss: 0.5492 - val_accuracy: 0.7207 - val_loss: 0.7415
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.8761 - loss: 0.5362 - val_accuracy: 0.8085 - val_loss: 0.6442
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.8992 - loss: 0.4786 - val_accuracy: 0.8218 - val_loss: 0.5983
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 204ms/step - accuracy: 0.9152 - loss: 0.4410 - val_accuracy: 0.8378 - val_loss: 0.5827
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.9341 - loss: 0.3978 - val_accuracy: 0.8218 - val_loss: 0.5677
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9368 - loss: 0.3743 - val_accuracy: 0.8564 - val_loss: 0.5172
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9483 - loss: 0.3504 - val_accuracy: 0.8431 - val_loss: 0.5205
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9353 - loss: 0.3554 - val_accuracy: 0.8351 - val_loss: 0.4986
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9532 - loss: 0.3149 - val_accuracy: 0.8697 - val_loss: 0.4570
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.9525 - loss: 0.2917 - val_accuracy: 0.8670 - val_loss: 0.4490
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9627 - loss: 0.2757 - val_accuracy: 0.8803 - val_loss: 0.4342
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9701 - loss: 0.2569 - val_accuracy: 0.8378 - val_loss: 0.4519
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.9721 - loss: 0.2513 - val_accuracy: 0.8830 - val_loss: 0.4060
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9751 - loss: 0.2397 - val_accuracy: 0.8697 - val_loss: 0.3994
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9511 - loss: 0.2542 - val_accuracy: 0.8723 - val_loss: 0.4070
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9836 - loss: 0.2055 - val_accuracy: 0.8723 - val_loss: 0.3909
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.9835 - loss: 0.1956 - val_accuracy: 0.8963 - val_loss: 0.3573
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9814 - loss: 0.1900 - val_accuracy: 0.8564 - val_loss: 0.4057
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9809 - loss: 0.1858 - val_accuracy: 0.9069 - val_loss: 0.3400
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.9939 - loss: 0.1713 - val_accuracy: 0.9043 - val_loss: 0.3366
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.9834 - loss: 0.1620 - val_accuracy: 0.9043 - val_loss: 0.3307
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.9855 - loss: 0.1716 - val_accuracy: 0.8856 - val_loss: 0.3294
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9910 - loss: 0.1461 - val_accuracy: 0.8963 - val_loss: 0.3206
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9878 - loss: 0.1481 - val_accuracy: 0.9016 - val_loss: 0.3152
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9861 - loss: 0.1541 - val_accuracy: 0.9202 - val_loss: 0.3006
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9927 - loss: 0.1408 - val_accuracy: 0.8989 - val_loss: 0.3108
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9936 - loss: 0.1391 - val_accuracy: 0.9149 - val_loss: 0.2895
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.9878 - loss: 0.1329 - val_accuracy: 0.9096 - val_loss: 0.2938
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.9956 - loss: 0.1203 - val_accuracy: 0.8963 - val_loss: 0.2908
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9947 - loss: 0.1080 - val_accuracy: 0.9149 - val_loss: 0.2751
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.9960 - loss: 0.1078 - val_accuracy: 0.9176 - val_loss: 0.2680
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9946 - loss: 0.1117 - val_accuracy: 0.9229 - val_loss: 0.2730
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.9967 - loss: 0.1041 - val_accuracy: 0.9282 - val_loss: 0.2700
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9974 - loss: 0.0934 - val_accuracy: 0.9176 - val_loss: 0.2678
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 166ms/step - accuracy: 0.9960 - loss: 0.0936 - val_accuracy: 0.9202 - val_loss: 0.2641
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9990 - loss: 0.0897 - val_accuracy: 0.9229 - val_loss: 0.2467
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9991 - loss: 0.0827 - val_accuracy: 0.9202 - val_loss: 0.2416
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9993 - loss: 0.0768 - val_accuracy: 0.9149 - val_loss: 0.2466
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9985 - loss: 0.0840 - val_accuracy: 0.9282 - val_loss: 0.2475
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9978 - loss: 0.0831 - val_accuracy: 0.9176 - val_loss: 0.2513
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9959 - loss: 0.0795 - val_accuracy: 0.9282 - val_loss: 0.2419
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9985 - loss: 0.0742 - val_accuracy: 0.9255 - val_loss: 0.2342
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9978 - loss: 0.0725 - val_accuracy: 0.9282 - val_loss: 0.2300
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9996 - loss: 0.0653 - val_accuracy: 0.9176 - val_loss: 0.2335
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.9999 - loss: 0.0660 - val_accuracy: 0.9122 - val_loss: 0.2352
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9987 - loss: 0.0611 - val_accuracy: 0.9309 - val_loss: 0.2249
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 0.9388 - val_loss: 0.2246
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.9989 - loss: 0.0676 - val_accuracy: 0.9176 - val_loss: 0.2367
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9993 - loss: 0.0587 - val_accuracy: 0.9122 - val_loss: 0.2250
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 1.0000 - loss: 0.0568 - val_accuracy: 0.9309 - val_loss: 0.2116
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.9999 - loss: 0.0547 - val_accuracy: 0.9255 - val_loss: 0.2104
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 1.0000 - loss: 0.0484 - val_accuracy: 0.9229 - val_loss: 0.2240
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9992 - loss: 0.0501 - val_accuracy: 0.9388 - val_loss: 0.2166
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 1.0000 - loss: 0.0485 - val_accuracy: 0.9255 - val_loss: 0.2088
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 1.0000 - loss: 0.0481 - val_accuracy: 0.9282 - val_loss: 0.2053
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 1.0000 - loss: 0.0436 - val_accuracy: 0.9282 - val_loss: 0.2041
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 1.0000 - loss: 0.0436 - val_accuracy: 0.9309 - val_loss: 0.2103
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 1.0000 - loss: 0.0439 - val_accuracy: 0.9255 - val_loss: 0.2111
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 1.0000 - loss: 0.0408 - val_accuracy: 0.9309 - val_loss: 0.1986
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 171ms/step - accuracy: 0.9995 - loss: 0.0414 - val_accuracy: 0.9255 - val_loss: 0.2057
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 0.9362 - val_loss: 0.2087
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 1.0000 - loss: 0.0372 - val_accuracy: 0.9309 - val_loss: 0.1958
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 1.0000 - loss: 0.0372 - val_accuracy: 0.9229 - val_loss: 0.2185
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 0.9441 - val_loss: 0.1981
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 1.0000 - loss: 0.0343 - val_accuracy: 0.9441 - val_loss: 0.1963
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 1.0000 - loss: 0.0348 - val_accuracy: 0.9335 - val_loss: 0.1955
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - accuracy: 1.0000 - loss: 0.0335 - val_accuracy: 0.9388 - val_loss: 0.1910
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 0.9415 - val_loss: 0.1868
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 1.0000 - loss: 0.0312 - val_accuracy: 0.9309 - val_loss: 0.1896
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - accuracy: 1.0000 - loss: 0.0324 - val_accuracy: 0.9309 - val_loss: 0.2068
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 1.0000 - loss: 0.0323 - val_accuracy: 0.9202 - val_loss: 0.1918
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 0.9362 - val_loss: 0.1843
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 1.0000 - loss: 0.0288 - val_accuracy: 0.9335 - val_loss: 0.1796
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 1.0000 - loss: 0.0284 - val_accuracy: 0.9362 - val_loss: 0.1932
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 1.0000 - loss: 0.0285 - val_accuracy: 0.9335 - val_loss: 0.1809
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 0.9362 - val_loss: 0.1817
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 1.0000 - loss: 0.0253 - val_accuracy: 0.9362 - val_loss: 0.1794
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.9335 - val_loss: 0.1779
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 1.0000 - loss: 0.0241 - val_accuracy: 0.9388 - val_loss: 0.1909
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.9415 - val_loss: 0.1817
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.9415 - val_loss: 0.1817
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 1.0000 - loss: 0.0252 - val_accuracy: 0.9388 - val_loss: 0.1797
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.9362 - val_loss: 0.1757
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 1.0000 - loss: 0.0197 - val_accuracy: 0.9362 - val_loss: 0.1759
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.9415 - val_loss: 0.1775
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.9282 - val_loss: 0.1807
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 1.0000 - loss: 0.0196 - val_accuracy: 0.9282 - val_loss: 0.1831
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.9335 - val_loss: 0.1806
# >>> Training completed in 1007.21 seconds.
# >>> Epochs completed: 95
# >>> Evaluating InceptionV3 on the Test data:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 967ms/step
# >>> Test Accuracy for InceptionV3: 94.21%.

# %% [markdown]
# ResNet50

# %%
import time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

print(">>> Training ResNet50 model:")
start_time = time.time()

result_resnet = custom_resnet_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

end_time = time.time()
elapsed_time = end_time - start_time
epochs_completed = len(result_resnet.history['loss'])

model_histories.append((result_resnet.history, "ResNet50"))

print(f">>> Training completed in {elapsed_time:.2f} seconds.")
print(f">>> Epochs completed: {epochs_completed}")

print(">>> Evaluating ResNet50 on the Test data:")
test_pred_resnet = custom_resnet_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy_resnet = accuracy_score(np.argmax(test_pred_resnet, axis=1), test_labels)
print(f">>> Test Accuracy for ResNet50: {test_accuracy_resnet * 100:.2f}%.")
# Out:
# >>> Training ResNet50 model:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 34s 417ms/step - accuracy: 0.2646 - loss: 1.4023 - val_accuracy: 0.2553 - val_loss: 1.4477
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.2485 - loss: 1.4099 - val_accuracy: 0.2606 - val_loss: 1.4250
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.2546 - loss: 1.4003 - val_accuracy: 0.2819 - val_loss: 1.3715
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.2781 - loss: 1.3750 - val_accuracy: 0.2500 - val_loss: 1.3921
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.2543 - loss: 1.3815 - val_accuracy: 0.2660 - val_loss: 1.3835
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.2987 - loss: 1.3683 - val_accuracy: 0.3883 - val_loss: 1.3916
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.3171 - loss: 1.3628 - val_accuracy: 0.3191 - val_loss: 1.3747
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.3059 - loss: 1.3659 - val_accuracy: 0.3165 - val_loss: 1.3657
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.2978 - loss: 1.3581 - val_accuracy: 0.3138 - val_loss: 1.3631
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.2955 - loss: 1.3652 - val_accuracy: 0.4176 - val_loss: 1.3470
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.3543 - loss: 1.3471 - val_accuracy: 0.2766 - val_loss: 1.3576
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.2914 - loss: 1.3510 - val_accuracy: 0.3431 - val_loss: 1.3437
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.3328 - loss: 1.3385 - val_accuracy: 0.2686 - val_loss: 1.3585
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.3411 - loss: 1.3389 - val_accuracy: 0.3883 - val_loss: 1.3463
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.3106 - loss: 1.3528 - val_accuracy: 0.3378 - val_loss: 1.3518
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.3394 - loss: 1.3376 - val_accuracy: 0.3351 - val_loss: 1.3383
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.3352 - loss: 1.3262 - val_accuracy: 0.4043 - val_loss: 1.3276
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 191ms/step - accuracy: 0.3798 - loss: 1.3148 - val_accuracy: 0.3511 - val_loss: 1.3295
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.3521 - loss: 1.3336 - val_accuracy: 0.3856 - val_loss: 1.3203
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.4187 - loss: 1.3114 - val_accuracy: 0.2926 - val_loss: 1.3654
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.3997 - loss: 1.3060 - val_accuracy: 0.3085 - val_loss: 1.3348
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.3587 - loss: 1.3135 - val_accuracy: 0.3803 - val_loss: 1.3309
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.3896 - loss: 1.3015 - val_accuracy: 0.4255 - val_loss: 1.3189
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.3948 - loss: 1.3000 - val_accuracy: 0.3963 - val_loss: 1.3079
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.3971 - loss: 1.2908 - val_accuracy: 0.3590 - val_loss: 1.3066
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.3831 - loss: 1.3043 - val_accuracy: 0.4176 - val_loss: 1.3150
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.4059 - loss: 1.2958 - val_accuracy: 0.3830 - val_loss: 1.3091
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 175ms/step - accuracy: 0.3999 - loss: 1.2949 - val_accuracy: 0.3218 - val_loss: 1.3334
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.4050 - loss: 1.2935 - val_accuracy: 0.2952 - val_loss: 1.3099
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.3534 - loss: 1.3104 - val_accuracy: 0.4441 - val_loss: 1.2955
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.4285 - loss: 1.2882 - val_accuracy: 0.3218 - val_loss: 1.3078
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.4086 - loss: 1.2887 - val_accuracy: 0.4654 - val_loss: 1.2917
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.4137 - loss: 1.2741 - val_accuracy: 0.4574 - val_loss: 1.2902
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.4107 - loss: 1.2848 - val_accuracy: 0.3883 - val_loss: 1.2956
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.4038 - loss: 1.2786 - val_accuracy: 0.4654 - val_loss: 1.2839
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.4304 - loss: 1.2703 - val_accuracy: 0.3324 - val_loss: 1.3015
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 187ms/step - accuracy: 0.3889 - loss: 1.2764 - val_accuracy: 0.3564 - val_loss: 1.2953
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.3997 - loss: 1.2744 - val_accuracy: 0.3431 - val_loss: 1.2913
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.4308 - loss: 1.2610 - val_accuracy: 0.3723 - val_loss: 1.2822
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.4235 - loss: 1.2645 - val_accuracy: 0.3378 - val_loss: 1.2927
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.3926 - loss: 1.2672 - val_accuracy: 0.3245 - val_loss: 1.2925
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.4655 - loss: 1.2509 - val_accuracy: 0.3803 - val_loss: 1.2894
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 172ms/step - accuracy: 0.4135 - loss: 1.2558 - val_accuracy: 0.3484 - val_loss: 1.3007
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.4041 - loss: 1.2600 - val_accuracy: 0.3511 - val_loss: 1.2710
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.4347 - loss: 1.2484 - val_accuracy: 0.3963 - val_loss: 1.2694
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.4110 - loss: 1.2603 - val_accuracy: 0.3750 - val_loss: 1.2755
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.4087 - loss: 1.2467 - val_accuracy: 0.3910 - val_loss: 1.2756
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.4475 - loss: 1.2418 - val_accuracy: 0.4043 - val_loss: 1.2662
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.4675 - loss: 1.2468 - val_accuracy: 0.4628 - val_loss: 1.2610
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - accuracy: 0.4068 - loss: 1.2531 - val_accuracy: 0.4574 - val_loss: 1.2562
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.4746 - loss: 1.2349 - val_accuracy: 0.3989 - val_loss: 1.2754
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.4867 - loss: 1.2372 - val_accuracy: 0.3803 - val_loss: 1.2605
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - accuracy: 0.4577 - loss: 1.2418 - val_accuracy: 0.3723 - val_loss: 1.2572
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.4305 - loss: 1.2364 - val_accuracy: 0.4016 - val_loss: 1.2865
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.4606 - loss: 1.2277 - val_accuracy: 0.3511 - val_loss: 1.2590
# >>> Training completed in 618.64 seconds.
# >>> Epochs completed: 55
# >>> Evaluating ResNet50 on the Test data:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 702ms/step
# >>> Test Accuracy for ResNet50: 47.89%.

# %% [markdown]
# MobileNetV2

# %%
import time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

print(">>> Training MobileNetV2 model:")
start_time = time.time()

result_mob = custom_mobilenet_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

end_time = time.time()
elapsed_time = end_time - start_time
epochs_completed = len(result_mob.history['loss'])

model_histories.append((result_mob.history, "MobileNetV2"))

print(f">>> Training completed in {elapsed_time:.2f} seconds.")
print(f">>> Epochs completed: {epochs_completed}")

print(">>> Evaluating MobileNetV2 on the Test data:")
test_pred_mob = custom_mobilenet_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy_mob = accuracy_score(np.argmax(test_pred_mob, axis=1), test_labels)
print(f">>> Test Accuracy for MobileNetV2: {test_accuracy_mob * 100:.2f}%.")
# Out:
# >>> Training MobileNetV2 model:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 30s 365ms/step - accuracy: 0.2471 - loss: 1.5610 - val_accuracy: 0.3378 - val_loss: 1.3512
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.3975 - loss: 1.2878 - val_accuracy: 0.5612 - val_loss: 1.1374
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.5648 - loss: 1.1014 - val_accuracy: 0.6170 - val_loss: 1.0370
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.6608 - loss: 0.9905 - val_accuracy: 0.6596 - val_loss: 0.9704
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.7129 - loss: 0.8966 - val_accuracy: 0.7553 - val_loss: 0.8721
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.7677 - loss: 0.8166 - val_accuracy: 0.7553 - val_loss: 0.8303
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.7860 - loss: 0.7635 - val_accuracy: 0.7899 - val_loss: 0.7479
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.8407 - loss: 0.6872 - val_accuracy: 0.7660 - val_loss: 0.7357
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.8408 - loss: 0.6454 - val_accuracy: 0.8245 - val_loss: 0.6744
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.8779 - loss: 0.5934 - val_accuracy: 0.8457 - val_loss: 0.6356
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.8787 - loss: 0.5584 - val_accuracy: 0.8245 - val_loss: 0.6202
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.8939 - loss: 0.5292 - val_accuracy: 0.7926 - val_loss: 0.6468
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.8842 - loss: 0.5159 - val_accuracy: 0.8723 - val_loss: 0.5532
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.9074 - loss: 0.4771 - val_accuracy: 0.8883 - val_loss: 0.5141
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.9248 - loss: 0.4438 - val_accuracy: 0.8936 - val_loss: 0.5081
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9188 - loss: 0.4261 - val_accuracy: 0.8856 - val_loss: 0.4759
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9233 - loss: 0.4118 - val_accuracy: 0.9043 - val_loss: 0.4664
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9242 - loss: 0.4005 - val_accuracy: 0.9096 - val_loss: 0.4338
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9467 - loss: 0.3548 - val_accuracy: 0.8936 - val_loss: 0.4509
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9461 - loss: 0.3627 - val_accuracy: 0.9096 - val_loss: 0.4247
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9517 - loss: 0.3252 - val_accuracy: 0.9069 - val_loss: 0.3986
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.9537 - loss: 0.3169 - val_accuracy: 0.9202 - val_loss: 0.3861
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9628 - loss: 0.2962 - val_accuracy: 0.9202 - val_loss: 0.3688
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.9635 - loss: 0.2850 - val_accuracy: 0.9362 - val_loss: 0.3612
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9664 - loss: 0.2826 - val_accuracy: 0.9202 - val_loss: 0.3597
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9543 - loss: 0.2880 - val_accuracy: 0.9495 - val_loss: 0.3297
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9649 - loss: 0.2630 - val_accuracy: 0.9335 - val_loss: 0.3376
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9728 - loss: 0.2538 - val_accuracy: 0.9521 - val_loss: 0.3116
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9699 - loss: 0.2503 - val_accuracy: 0.9495 - val_loss: 0.3116
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.9757 - loss: 0.2347 - val_accuracy: 0.9468 - val_loss: 0.3133
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9767 - loss: 0.2250 - val_accuracy: 0.9468 - val_loss: 0.3097
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9830 - loss: 0.2132 - val_accuracy: 0.9521 - val_loss: 0.2943
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - accuracy: 0.9835 - loss: 0.2032 - val_accuracy: 0.9654 - val_loss: 0.2761
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.9828 - loss: 0.2039 - val_accuracy: 0.9628 - val_loss: 0.2704
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9873 - loss: 0.1929 - val_accuracy: 0.9548 - val_loss: 0.2710
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.9853 - loss: 0.1978 - val_accuracy: 0.9654 - val_loss: 0.2638
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9889 - loss: 0.1850 - val_accuracy: 0.9601 - val_loss: 0.2692
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9888 - loss: 0.1777 - val_accuracy: 0.9654 - val_loss: 0.2512
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.9902 - loss: 0.1765 - val_accuracy: 0.9681 - val_loss: 0.2359
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9853 - loss: 0.1754 - val_accuracy: 0.9681 - val_loss: 0.2336
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.9904 - loss: 0.1628 - val_accuracy: 0.9681 - val_loss: 0.2264
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 171ms/step - accuracy: 0.9885 - loss: 0.1710 - val_accuracy: 0.9601 - val_loss: 0.2343
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.9911 - loss: 0.1551 - val_accuracy: 0.9628 - val_loss: 0.2206
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9883 - loss: 0.1546 - val_accuracy: 0.9734 - val_loss: 0.2189
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9931 - loss: 0.1449 - val_accuracy: 0.9654 - val_loss: 0.2125
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9922 - loss: 0.1487 - val_accuracy: 0.9601 - val_loss: 0.2087
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.9885 - loss: 0.1396 - val_accuracy: 0.9707 - val_loss: 0.2133
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9946 - loss: 0.1325 - val_accuracy: 0.9654 - val_loss: 0.2013
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.9914 - loss: 0.1314 - val_accuracy: 0.9707 - val_loss: 0.1937
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 159ms/step - accuracy: 0.9931 - loss: 0.1224 - val_accuracy: 0.9734 - val_loss: 0.1941
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9953 - loss: 0.1184 - val_accuracy: 0.9814 - val_loss: 0.1934
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9952 - loss: 0.1294 - val_accuracy: 0.9761 - val_loss: 0.1834
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - accuracy: 0.9930 - loss: 0.1173 - val_accuracy: 0.9734 - val_loss: 0.1854
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9963 - loss: 0.1144 - val_accuracy: 0.9707 - val_loss: 0.1868
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9990 - loss: 0.1111 - val_accuracy: 0.9734 - val_loss: 0.1820
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.9935 - loss: 0.1113 - val_accuracy: 0.9787 - val_loss: 0.1723
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9962 - loss: 0.1012 - val_accuracy: 0.9787 - val_loss: 0.1687
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9984 - loss: 0.0978 - val_accuracy: 0.9734 - val_loss: 0.1714
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9961 - loss: 0.0985 - val_accuracy: 0.9734 - val_loss: 0.1729
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.9980 - loss: 0.0934 - val_accuracy: 0.9787 - val_loss: 0.1587
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.9966 - loss: 0.0903 - val_accuracy: 0.9761 - val_loss: 0.1590
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 165ms/step - accuracy: 0.9969 - loss: 0.0897 - val_accuracy: 0.9814 - val_loss: 0.1553
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.9976 - loss: 0.0878 - val_accuracy: 0.9761 - val_loss: 0.1512
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9981 - loss: 0.0870 - val_accuracy: 0.9761 - val_loss: 0.1518
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9993 - loss: 0.0836 - val_accuracy: 0.9814 - val_loss: 0.1544
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.9962 - loss: 0.0821 - val_accuracy: 0.9787 - val_loss: 0.1461
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9988 - loss: 0.0809 - val_accuracy: 0.9787 - val_loss: 0.1469
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9985 - loss: 0.0702 - val_accuracy: 0.9707 - val_loss: 0.1457
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9991 - loss: 0.0755 - val_accuracy: 0.9761 - val_loss: 0.1444
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9986 - loss: 0.0721 - val_accuracy: 0.9787 - val_loss: 0.1449
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9963 - loss: 0.0762 - val_accuracy: 0.9814 - val_loss: 0.1375
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9981 - loss: 0.0691 - val_accuracy: 0.9761 - val_loss: 0.1382
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9981 - loss: 0.0674 - val_accuracy: 0.9787 - val_loss: 0.1342
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9993 - loss: 0.0671 - val_accuracy: 0.9761 - val_loss: 0.1325
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9999 - loss: 0.0623 - val_accuracy: 0.9814 - val_loss: 0.1327
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 162ms/step - accuracy: 0.9994 - loss: 0.0623 - val_accuracy: 0.9761 - val_loss: 0.1287
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9991 - loss: 0.0603 - val_accuracy: 0.9787 - val_loss: 0.1265
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9997 - loss: 0.0616 - val_accuracy: 0.9840 - val_loss: 0.1219
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9999 - loss: 0.0601 - val_accuracy: 0.9814 - val_loss: 0.1230
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 1.0000 - loss: 0.0585 - val_accuracy: 0.9761 - val_loss: 0.1265
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9972 - loss: 0.0584 - val_accuracy: 0.9734 - val_loss: 0.1254
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9999 - loss: 0.0554 - val_accuracy: 0.9787 - val_loss: 0.1336
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9990 - loss: 0.0536 - val_accuracy: 0.9814 - val_loss: 0.1190
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 1.0000 - loss: 0.0531 - val_accuracy: 0.9787 - val_loss: 0.1221
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.9998 - loss: 0.0512 - val_accuracy: 0.9734 - val_loss: 0.1134
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9986 - loss: 0.0517 - val_accuracy: 0.9787 - val_loss: 0.1141
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9997 - loss: 0.0522 - val_accuracy: 0.9787 - val_loss: 0.1149
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9994 - loss: 0.0480 - val_accuracy: 0.9814 - val_loss: 0.1096
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 174ms/step - accuracy: 0.9998 - loss: 0.0457 - val_accuracy: 0.9840 - val_loss: 0.1081
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9994 - loss: 0.0441 - val_accuracy: 0.9787 - val_loss: 0.1098
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 1.0000 - loss: 0.0435 - val_accuracy: 0.9787 - val_loss: 0.1064
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - accuracy: 1.0000 - loss: 0.0431 - val_accuracy: 0.9814 - val_loss: 0.1051
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 1.0000 - loss: 0.0415 - val_accuracy: 0.9761 - val_loss: 0.1049
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 0.9814 - val_loss: 0.1061
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 1.0000 - loss: 0.0410 - val_accuracy: 0.9761 - val_loss: 0.1006
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9985 - loss: 0.0398 - val_accuracy: 0.9787 - val_loss: 0.1007
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.9814 - val_loss: 0.1130
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 1.0000 - loss: 0.0396 - val_accuracy: 0.9840 - val_loss: 0.0977
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 1.0000 - loss: 0.0392 - val_accuracy: 0.9814 - val_loss: 0.0990
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 1.0000 - loss: 0.0367 - val_accuracy: 0.9840 - val_loss: 0.0998
# >>> Training completed in 989.55 seconds.
# >>> Epochs completed: 100
# >>> Evaluating MobileNetV2 on the Test data:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 609ms/step
# >>> Test Accuracy for MobileNetV2: 96.84%.

# %% [markdown]
# EfficientNetB0

# %%
import time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

print(">>> Training EfficientNetB0 model:")
start_time = time.time()

result_eff = custom_efficientnet_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

end_time = time.time()
elapsed_time = end_time - start_time
epochs_completed = len(result_eff.history['loss'])

model_histories.append((result_eff.history, "EfficientNetB0"))

print(f">>> Training completed in {elapsed_time:.2f} seconds.")
print(f">>> Epochs completed: {epochs_completed}")

print(">>> Evaluating EfficientNetB0 on the Test data:")
test_pred_eff = custom_efficientnet_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy_eff = accuracy_score(np.argmax(test_pred_eff, axis=1), test_labels)
print(f">>> Test Accuracy for EfficientNetB0: {test_accuracy_eff * 100:.2f}%.")
# Out:
# >>> Training EfficientNetB0 model:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.2896 - loss: 1.4018 - val_accuracy: 0.2500 - val_loss: 1.3964
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 216ms/step - accuracy: 0.2597 - loss: 1.3942 - val_accuracy: 0.2500 - val_loss: 1.3887
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.2695 - loss: 1.4001 - val_accuracy: 0.2500 - val_loss: 1.4025
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.2349 - loss: 1.4041 - val_accuracy: 0.2500 - val_loss: 1.3881
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.2560 - loss: 1.3996 - val_accuracy: 0.2500 - val_loss: 1.4334
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.2466 - loss: 1.4100 - val_accuracy: 0.2500 - val_loss: 1.3952
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.2409 - loss: 1.4045 - val_accuracy: 0.2500 - val_loss: 1.3878
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.2734 - loss: 1.4038 - val_accuracy: 0.2500 - val_loss: 1.4076
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - accuracy: 0.2303 - loss: 1.4064 - val_accuracy: 0.2500 - val_loss: 1.3869
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.2465 - loss: 1.3953 - val_accuracy: 0.2500 - val_loss: 1.3982
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.2454 - loss: 1.4000 - val_accuracy: 0.2500 - val_loss: 1.4027
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step - accuracy: 0.2533 - loss: 1.4016 - val_accuracy: 0.2500 - val_loss: 1.3955
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.2475 - loss: 1.3965 - val_accuracy: 0.2500 - val_loss: 1.4081
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.2550 - loss: 1.3974 - val_accuracy: 0.2500 - val_loss: 1.3968
# >>> Training completed in 145.59 seconds.
# >>> Epochs completed: 14
# >>> Evaluating EfficientNetB0 on the Test data:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 886ms/step
# >>> Test Accuracy for EfficientNetB0: 25.00%.

# %% [markdown]
# DenseNet121

# %%
import time
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

print(">>> Training DenseNet121 model:")
start_time = time.time()

result_densenet = custom_densenet_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

end_time = time.time()
elapsed_time = end_time - start_time
epochs_completed = len(result_densenet.history['loss'])

model_histories.append((result_densenet.history, "DenseNet121"))

print(f">>> Training completed in {elapsed_time:.2f} seconds.")
print(f">>> Epochs completed: {epochs_completed}")

print(">>> Evaluating DenseNet121 on the Test data:")
test_pred_densenet = custom_densenet_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy_densenet = accuracy_score(np.argmax(test_pred_densenet, axis=1), test_labels)
print(f">>> Test Accuracy for DenseNet121: {test_accuracy_densenet * 100:.2f}%.")
# Out:
# >>> Training DenseNet121 model:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 92s 938ms/step - accuracy: 0.2699 - loss: 1.5129 - val_accuracy: 0.3112 - val_loss: 1.4038
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.3191 - loss: 1.3670 - val_accuracy: 0.3910 - val_loss: 1.3196
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.4149 - loss: 1.2790 - val_accuracy: 0.4548 - val_loss: 1.2620
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.5169 - loss: 1.1910 - val_accuracy: 0.4548 - val_loss: 1.2252
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.5526 - loss: 1.1464 - val_accuracy: 0.5053 - val_loss: 1.1737
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.5932 - loss: 1.0977 - val_accuracy: 0.5957 - val_loss: 1.1060
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.6499 - loss: 1.0404 - val_accuracy: 0.6170 - val_loss: 1.0846
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 188ms/step - accuracy: 0.6706 - loss: 1.0041 - val_accuracy: 0.6197 - val_loss: 1.0557
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.7158 - loss: 0.9598 - val_accuracy: 0.6995 - val_loss: 1.0043
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7273 - loss: 0.9115 - val_accuracy: 0.6755 - val_loss: 0.9878
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.7139 - loss: 0.9094 - val_accuracy: 0.6144 - val_loss: 1.0130
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.7243 - loss: 0.8689 - val_accuracy: 0.7181 - val_loss: 0.9287
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.7356 - loss: 0.8422 - val_accuracy: 0.7207 - val_loss: 0.8977
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.8200 - loss: 0.7911 - val_accuracy: 0.7287 - val_loss: 0.8801
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.7816 - loss: 0.7892 - val_accuracy: 0.7154 - val_loss: 0.8635
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.7656 - loss: 0.7906 - val_accuracy: 0.7340 - val_loss: 0.8408
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.8106 - loss: 0.7332 - val_accuracy: 0.7553 - val_loss: 0.8229
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.8138 - loss: 0.7178 - val_accuracy: 0.7367 - val_loss: 0.8247
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8352 - loss: 0.6920 - val_accuracy: 0.7340 - val_loss: 0.8135
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.8415 - loss: 0.6678 - val_accuracy: 0.7872 - val_loss: 0.7582
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.8498 - loss: 0.6575 - val_accuracy: 0.8059 - val_loss: 0.7383
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - accuracy: 0.8511 - loss: 0.6415 - val_accuracy: 0.8138 - val_loss: 0.7224
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.8648 - loss: 0.6180 - val_accuracy: 0.8032 - val_loss: 0.7283
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.8643 - loss: 0.6130 - val_accuracy: 0.8298 - val_loss: 0.6957
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.8840 - loss: 0.5782 - val_accuracy: 0.7846 - val_loss: 0.7077
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.8622 - loss: 0.6015 - val_accuracy: 0.8271 - val_loss: 0.6744
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.8863 - loss: 0.5772 - val_accuracy: 0.8245 - val_loss: 0.6605
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.8811 - loss: 0.5642 - val_accuracy: 0.8271 - val_loss: 0.6532
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.8945 - loss: 0.5478 - val_accuracy: 0.8298 - val_loss: 0.6425
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.8944 - loss: 0.5394 - val_accuracy: 0.8404 - val_loss: 0.6361
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.8949 - loss: 0.5326 - val_accuracy: 0.8191 - val_loss: 0.6331
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.8997 - loss: 0.5137 - val_accuracy: 0.8378 - val_loss: 0.6148
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.8880 - loss: 0.5123 - val_accuracy: 0.8191 - val_loss: 0.6215
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - accuracy: 0.8952 - loss: 0.4989 - val_accuracy: 0.8457 - val_loss: 0.6122
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.8933 - loss: 0.5046 - val_accuracy: 0.8564 - val_loss: 0.5860
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9016 - loss: 0.5003 - val_accuracy: 0.8537 - val_loss: 0.5732
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9238 - loss: 0.4644 - val_accuracy: 0.8271 - val_loss: 0.5876
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9067 - loss: 0.4685 - val_accuracy: 0.8723 - val_loss: 0.5591
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9221 - loss: 0.4441 - val_accuracy: 0.8511 - val_loss: 0.5555
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9285 - loss: 0.4373 - val_accuracy: 0.8191 - val_loss: 0.5707
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9120 - loss: 0.4482 - val_accuracy: 0.8484 - val_loss: 0.5472
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9267 - loss: 0.4289 - val_accuracy: 0.8723 - val_loss: 0.5324
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9196 - loss: 0.4306 - val_accuracy: 0.8537 - val_loss: 0.5238
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9182 - loss: 0.4190 - val_accuracy: 0.8670 - val_loss: 0.5254
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9257 - loss: 0.4179 - val_accuracy: 0.8670 - val_loss: 0.5213
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9442 - loss: 0.3901 - val_accuracy: 0.8590 - val_loss: 0.5166
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - accuracy: 0.9393 - loss: 0.3774 - val_accuracy: 0.8644 - val_loss: 0.5037
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9177 - loss: 0.3958 - val_accuracy: 0.8457 - val_loss: 0.5119
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - accuracy: 0.9411 - loss: 0.3841 - val_accuracy: 0.8777 - val_loss: 0.4908
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9372 - loss: 0.3666 - val_accuracy: 0.8856 - val_loss: 0.4824
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9474 - loss: 0.3562 - val_accuracy: 0.8803 - val_loss: 0.4835
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9496 - loss: 0.3644 - val_accuracy: 0.8883 - val_loss: 0.4677
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9451 - loss: 0.3546 - val_accuracy: 0.8910 - val_loss: 0.4646
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9522 - loss: 0.3434 - val_accuracy: 0.8830 - val_loss: 0.4614
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9508 - loss: 0.3414 - val_accuracy: 0.8564 - val_loss: 0.4748
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9435 - loss: 0.3524 - val_accuracy: 0.8750 - val_loss: 0.4533
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9446 - loss: 0.3352 - val_accuracy: 0.8856 - val_loss: 0.4455
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9538 - loss: 0.3274 - val_accuracy: 0.8830 - val_loss: 0.4493
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9505 - loss: 0.3283 - val_accuracy: 0.8963 - val_loss: 0.4341
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9542 - loss: 0.3220 - val_accuracy: 0.8910 - val_loss: 0.4291
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9545 - loss: 0.3136 - val_accuracy: 0.9016 - val_loss: 0.4295
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9519 - loss: 0.3151 - val_accuracy: 0.8883 - val_loss: 0.4275
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.9632 - loss: 0.3076 - val_accuracy: 0.8963 - val_loss: 0.4219
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9601 - loss: 0.2941 - val_accuracy: 0.9069 - val_loss: 0.4139
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.9545 - loss: 0.2994 - val_accuracy: 0.8750 - val_loss: 0.4405
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9604 - loss: 0.3000 - val_accuracy: 0.8910 - val_loss: 0.4176
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9575 - loss: 0.2889 - val_accuracy: 0.8989 - val_loss: 0.4044
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.9554 - loss: 0.2889 - val_accuracy: 0.8750 - val_loss: 0.4306
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9685 - loss: 0.2802 - val_accuracy: 0.8910 - val_loss: 0.4146
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - accuracy: 0.9650 - loss: 0.2783 - val_accuracy: 0.9069 - val_loss: 0.3924
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9586 - loss: 0.2797 - val_accuracy: 0.8910 - val_loss: 0.4058
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.9652 - loss: 0.2722 - val_accuracy: 0.8856 - val_loss: 0.4037
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.9729 - loss: 0.2656 - val_accuracy: 0.9043 - val_loss: 0.3860
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9642 - loss: 0.2650 - val_accuracy: 0.8963 - val_loss: 0.3881
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - accuracy: 0.9699 - loss: 0.2621 - val_accuracy: 0.9016 - val_loss: 0.3890
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9688 - loss: 0.2534 - val_accuracy: 0.8963 - val_loss: 0.3880
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.9651 - loss: 0.2703 - val_accuracy: 0.8963 - val_loss: 0.3784
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - accuracy: 0.9675 - loss: 0.2529 - val_accuracy: 0.9122 - val_loss: 0.3654
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.9729 - loss: 0.2523 - val_accuracy: 0.9069 - val_loss: 0.3696
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9648 - loss: 0.2410 - val_accuracy: 0.9069 - val_loss: 0.3659
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.9763 - loss: 0.2356 - val_accuracy: 0.8963 - val_loss: 0.3747
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.9677 - loss: 0.2384 - val_accuracy: 0.9069 - val_loss: 0.3598
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.9662 - loss: 0.2348 - val_accuracy: 0.9043 - val_loss: 0.3630
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.9729 - loss: 0.2330 - val_accuracy: 0.9016 - val_loss: 0.3645
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 162ms/step - accuracy: 0.9702 - loss: 0.2295 - val_accuracy: 0.9016 - val_loss: 0.3643
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9726 - loss: 0.2337 - val_accuracy: 0.9202 - val_loss: 0.3476
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 208ms/step - accuracy: 0.9797 - loss: 0.2194 - val_accuracy: 0.9096 - val_loss: 0.3570
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.9776 - loss: 0.2182 - val_accuracy: 0.9122 - val_loss: 0.3403
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9788 - loss: 0.2199 - val_accuracy: 0.9255 - val_loss: 0.3402
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.9697 - loss: 0.2275 - val_accuracy: 0.9096 - val_loss: 0.3397
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9717 - loss: 0.2240 - val_accuracy: 0.9122 - val_loss: 0.3374
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9741 - loss: 0.2139 - val_accuracy: 0.8963 - val_loss: 0.3616
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9729 - loss: 0.2158 - val_accuracy: 0.9202 - val_loss: 0.3281
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9679 - loss: 0.2098 - val_accuracy: 0.9202 - val_loss: 0.3328
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9803 - loss: 0.2019 - val_accuracy: 0.9176 - val_loss: 0.3325
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.9754 - loss: 0.2131 - val_accuracy: 0.9309 - val_loss: 0.3242
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - accuracy: 0.9784 - loss: 0.1990 - val_accuracy: 0.9202 - val_loss: 0.3179
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9776 - loss: 0.2022 - val_accuracy: 0.9255 - val_loss: 0.3227
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9795 - loss: 0.2022 - val_accuracy: 0.9043 - val_loss: 0.3443
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.9799 - loss: 0.1842 - val_accuracy: 0.9016 - val_loss: 0.3231
# >>> Training completed in 1126.63 seconds.
# >>> Epochs completed: 100
# >>> Evaluating DenseNet121 on the Test data:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step
# >>> Test Accuracy for DenseNet121: 91.58%.

# %% [markdown]
# FOCUSED: ONLY DENSENET121
# AFTER ENHANCEMENT

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
import numpy as np

model_densenet = DenseNet121(include_top=False, input_shape=(224, 224, 3))

# Define the DenseNet121 model with a custom top
base_model = DenseNet121(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))
base_model.trainable = False  # Freeze base for initial training

# >>> Custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)

x = Dense(512)(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.5)(x)

x = Dense(256)(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(0.4)(x)

output = Dense(4, activation='softmax')(x)  # Final output for 4 emotion classes

# Final model
custom_densenet_model = Model(inputs=base_model.input, outputs=output)

# Compile
custom_densenet_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the DenseNet121 model
print(">>> Training DenseNet121 model:")

result = custom_densenet_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

# Store the training history
model_histories = [(result.history, "DenseNet121")]

# Evaluate on the test data
print(">>> Evaluating DenseNet121 on the Test data:")
test_pred = custom_densenet_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy = accuracy_score(np.argmax(test_pred, axis=1), test_labels)
print(f">>> Test Accuracy for DenseNet121: {test_accuracy * 100:.2f}%.")
# Out:
# >>> Training DenseNet121 model:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_2155']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 74s 798ms/step - accuracy: 0.2721 - loss: 1.8598 - val_accuracy: 0.3298 - val_loss: 1.3986
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 243ms/step - accuracy: 0.3959 - loss: 1.5423 - val_accuracy: 0.4202 - val_loss: 1.2661
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 224ms/step - accuracy: 0.3869 - loss: 1.4812 - val_accuracy: 0.5479 - val_loss: 1.1444
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 224ms/step - accuracy: 0.4326 - loss: 1.2957 - val_accuracy: 0.6330 - val_loss: 1.0271
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 235ms/step - accuracy: 0.4587 - loss: 1.2594 - val_accuracy: 0.6782 - val_loss: 0.9337
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 228ms/step - accuracy: 0.5129 - loss: 1.1409 - val_accuracy: 0.7340 - val_loss: 0.8392
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 224ms/step - accuracy: 0.5394 - loss: 1.1242 - val_accuracy: 0.7872 - val_loss: 0.7611
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.5987 - loss: 0.9893 - val_accuracy: 0.7926 - val_loss: 0.7144
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 223ms/step - accuracy: 0.6344 - loss: 0.8992 - val_accuracy: 0.8218 - val_loss: 0.6451
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 235ms/step - accuracy: 0.6490 - loss: 0.8619 - val_accuracy: 0.8484 - val_loss: 0.5817
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 230ms/step - accuracy: 0.6519 - loss: 0.8375 - val_accuracy: 0.8777 - val_loss: 0.5413
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.7103 - loss: 0.7543 - val_accuracy: 0.8617 - val_loss: 0.5068
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 226ms/step - accuracy: 0.6978 - loss: 0.7055 - val_accuracy: 0.8750 - val_loss: 0.4602
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 236ms/step - accuracy: 0.7807 - loss: 0.6204 - val_accuracy: 0.8910 - val_loss: 0.4245
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.7648 - loss: 0.5912 - val_accuracy: 0.8989 - val_loss: 0.3960
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.7895 - loss: 0.5489 - val_accuracy: 0.9016 - val_loss: 0.3744
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.7789 - loss: 0.5401 - val_accuracy: 0.8989 - val_loss: 0.3608
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 227ms/step - accuracy: 0.8214 - loss: 0.4885 - val_accuracy: 0.9122 - val_loss: 0.3216
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 226ms/step - accuracy: 0.8348 - loss: 0.4671 - val_accuracy: 0.9176 - val_loss: 0.3200
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.8470 - loss: 0.4262 - val_accuracy: 0.9335 - val_loss: 0.2954
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 223ms/step - accuracy: 0.8539 - loss: 0.4044 - val_accuracy: 0.9096 - val_loss: 0.2915
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 219ms/step - accuracy: 0.8486 - loss: 0.3934 - val_accuracy: 0.9229 - val_loss: 0.2672
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 229ms/step - accuracy: 0.8800 - loss: 0.3480 - val_accuracy: 0.9335 - val_loss: 0.2538
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.8808 - loss: 0.3373 - val_accuracy: 0.9388 - val_loss: 0.2343
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 222ms/step - accuracy: 0.8682 - loss: 0.3660 - val_accuracy: 0.9335 - val_loss: 0.2254
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 231ms/step - accuracy: 0.9078 - loss: 0.2825 - val_accuracy: 0.9335 - val_loss: 0.2184
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.8868 - loss: 0.2972 - val_accuracy: 0.9495 - val_loss: 0.2033
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 230ms/step - accuracy: 0.8986 - loss: 0.2858 - val_accuracy: 0.9441 - val_loss: 0.1990
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.8946 - loss: 0.2701 - val_accuracy: 0.9362 - val_loss: 0.2035
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 225ms/step - accuracy: 0.9234 - loss: 0.2309 - val_accuracy: 0.9415 - val_loss: 0.1999
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 225ms/step - accuracy: 0.9116 - loss: 0.2490 - val_accuracy: 0.9415 - val_loss: 0.1892
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 223ms/step - accuracy: 0.9183 - loss: 0.2290 - val_accuracy: 0.9495 - val_loss: 0.1986
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.9104 - loss: 0.2433 - val_accuracy: 0.9441 - val_loss: 0.1694
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 216ms/step - accuracy: 0.9224 - loss: 0.2288 - val_accuracy: 0.9441 - val_loss: 0.1713
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 215ms/step - accuracy: 0.9343 - loss: 0.2117 - val_accuracy: 0.9468 - val_loss: 0.1695
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 237ms/step - accuracy: 0.9211 - loss: 0.2171 - val_accuracy: 0.9495 - val_loss: 0.1770
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 216ms/step - accuracy: 0.9544 - loss: 0.1762 - val_accuracy: 0.9495 - val_loss: 0.1599
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.9396 - loss: 0.1884 - val_accuracy: 0.9415 - val_loss: 0.1679
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 21s 223ms/step - accuracy: 0.9313 - loss: 0.1890 - val_accuracy: 0.9468 - val_loss: 0.1646
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 231ms/step - accuracy: 0.9480 - loss: 0.1670 - val_accuracy: 0.9441 - val_loss: 0.1593
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 220ms/step - accuracy: 0.9501 - loss: 0.1754 - val_accuracy: 0.9521 - val_loss: 0.1511
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.9478 - loss: 0.1514 - val_accuracy: 0.9548 - val_loss: 0.1553
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 221ms/step - accuracy: 0.9471 - loss: 0.1500 - val_accuracy: 0.9548 - val_loss: 0.1487
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 233ms/step - accuracy: 0.9301 - loss: 0.1913 - val_accuracy: 0.9548 - val_loss: 0.1410
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 214ms/step - accuracy: 0.9537 - loss: 0.1437 - val_accuracy: 0.9495 - val_loss: 0.1411
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 236ms/step - accuracy: 0.9495 - loss: 0.1525 - val_accuracy: 0.9521 - val_loss: 0.1389
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 234ms/step - accuracy: 0.9542 - loss: 0.1268 - val_accuracy: 0.9495 - val_loss: 0.1365
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 232ms/step - accuracy: 0.9657 - loss: 0.1132 - val_accuracy: 0.9468 - val_loss: 0.1347
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 217ms/step - accuracy: 0.9634 - loss: 0.1365 - val_accuracy: 0.9574 - val_loss: 0.1322
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 13s 228ms/step - accuracy: 0.9636 - loss: 0.1119 - val_accuracy: 0.9521 - val_loss: 0.1222
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 219ms/step - accuracy: 0.9604 - loss: 0.1233 - val_accuracy: 0.9468 - val_loss: 0.1280
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 262ms/step - accuracy: 0.9663 - loss: 0.1171 - val_accuracy: 0.9548 - val_loss: 0.1330
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 213ms/step - accuracy: 0.9695 - loss: 0.1079 - val_accuracy: 0.9574 - val_loss: 0.1296
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 218ms/step - accuracy: 0.9722 - loss: 0.0962 - val_accuracy: 0.9521 - val_loss: 0.1330
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 212ms/step - accuracy: 0.9541 - loss: 0.1277 - val_accuracy: 0.9601 - val_loss: 0.1331
# >>> Evaluating DenseNet121 on the Test data:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_2155']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step
# >>> Test Accuracy for DenseNet121: 98.42%.
