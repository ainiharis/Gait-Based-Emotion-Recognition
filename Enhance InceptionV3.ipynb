# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score
import os # Importing the os module

# Specifying train, valid and test directory paths
# Use os.path.join to create correct paths
train_path = os.path.join('/content/drive/MyDrive/FYP/dataset', 'train')
valid_path = os.path.join('/content/drive/MyDrive/FYP/dataset', 'validation')
test_path = os.path.join('/content/drive/MyDrive/FYP/dataset', 'test')

# Rescaling the image
train_batches = ImageDataGenerator(rescale=1.0 / 255.0)
valid_batches = ImageDataGenerator(rescale=1.0 / 255.0)
test_batches = ImageDataGenerator(rescale=1.0 / 255.0)

# %%
# Train data generator
train_gen = train_batches.flow_from_directory(
    directory=train_path,
    target_size=(224, 224),
    classes=['angry', 'happy', 'neutral', 'sad'],
    batch_size=32
)

# Valid data generator
valid_gen = valid_batches.flow_from_directory(
    directory=valid_path,
    target_size=(224, 224),
    classes=['angry', 'happy', 'neutral', 'sad'],
    batch_size=32
)

# Test data generator
test_gen = test_batches.flow_from_directory(
    directory=test_path,
    target_size=(224, 224),
    classes=['angry', 'happy', 'neutral', 'sad'],
    batch_size=32,
    shuffle=False
)
# Out:
# Found 1764 images belonging to 4 classes.
# Found 376 images belonging to 4 classes.
# Found 380 images belonging to 4 classes.

# %%
#Initializing models
from tensorflow.keras.applications import InceptionV3

model_inception = InceptionV3(include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Freezing the layers so that they cannot be trained again
names = [model_inception]
for model in names:
    # Iterating all the layers in the pre-trained model
    for layer in model.layers:
        # Making trainable layers set to False
        layer.trainable = False

# %%
# Fine-tuning the pre-trained models
output_classes = len(train_gen.class_indices)

# Custom Inception model
custom_inc_model = Sequential([
    model_inception,
    GlobalAveragePooling2D(),
    Dense(output_classes, activation='softmax')
])

# %%
# Compiling the models
models = [custom_inc_model]

for model in models:
    model.compile(
        optimizer='Adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

# %% [markdown]
# MODIFIED LAYER

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import ReLU
from sklearn.metrics import accuracy_score
import numpy as np
import time  # Added for execution time measurement

model_inception = InceptionV3(include_top=False, input_shape=(224, 224, 3))

# Define the InceptionV3 model with a custom top
base_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))
base_model.trainable = False  # Freeze base for initial training

# >>> Custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)

x = Dense(512)(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Dropout(0.3)(x)

x = Dense(256)(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Dropout(0.3)(x)

output = Dense(4, activation='softmax')(x)  # Final output for 4 emotion classes

# Final model
custom_inception_model = Model(inputs=base_model.input, outputs=output)

# Compile
custom_inception_model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# >>> Start timer
start_time = time.time()

# Train the InceptionV3 model
print(">>> Training InceptionV3 model:")

result = custom_inception_model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=100,
    callbacks=[early_stopping],
    verbose=1
)

# Store the training history
model_histories = [(result.history, "InceptionV3")]

# Evaluate on the test data
print(">>> Evaluating InceptionV3 on the Test data:")
test_pred = custom_inception_model.predict(test_gen)
test_labels = test_gen.classes
test_accuracy = accuracy_score(np.argmax(test_pred, axis=1), test_labels)
print(f">>> Test Accuracy for InceptionV3: {test_accuracy * 100:.2f}%.")

# >>> End timer and print execution time
end_time = time.time()
execution_time = end_time - start_time
minutes, seconds = divmod(execution_time, 60)
print(f">>> Total execution time: {int(minutes)} minutes and {int(seconds)} seconds.")
# Out:
# >>> Training InceptionV3 model:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_626']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 649s 11s/step - accuracy: 0.2585 - loss: 1.7844 - val_accuracy: 0.4388 - val_loss: 1.2791
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.4842 - loss: 1.2026 - val_accuracy: 0.6463 - val_loss: 0.9949
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 145ms/step - accuracy: 0.6332 - loss: 0.8983 - val_accuracy: 0.7766 - val_loss: 0.7785
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.7553 - loss: 0.6903 - val_accuracy: 0.8590 - val_loss: 0.6072
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.8100 - loss: 0.5856 - val_accuracy: 0.8963 - val_loss: 0.4898
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 146ms/step - accuracy: 0.8493 - loss: 0.4893 - val_accuracy: 0.9016 - val_loss: 0.4029
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.9024 - loss: 0.3820 - val_accuracy: 0.9122 - val_loss: 0.3645
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9163 - loss: 0.3251 - val_accuracy: 0.9415 - val_loss: 0.2967
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - accuracy: 0.9253 - loss: 0.2754 - val_accuracy: 0.9362 - val_loss: 0.2667
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9500 - loss: 0.2537 - val_accuracy: 0.9495 - val_loss: 0.2349
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.9449 - loss: 0.2220 - val_accuracy: 0.9548 - val_loss: 0.2249
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 148ms/step - accuracy: 0.9613 - loss: 0.2005 - val_accuracy: 0.9495 - val_loss: 0.2013
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.9673 - loss: 0.1740 - val_accuracy: 0.9574 - val_loss: 0.1766
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9787 - loss: 0.1434 - val_accuracy: 0.9654 - val_loss: 0.1706
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 150ms/step - accuracy: 0.9734 - loss: 0.1446 - val_accuracy: 0.9601 - val_loss: 0.1529
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.9801 - loss: 0.1207 - val_accuracy: 0.9628 - val_loss: 0.1435
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9820 - loss: 0.1023 - val_accuracy: 0.9628 - val_loss: 0.1380
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.9895 - loss: 0.0896 - val_accuracy: 0.9654 - val_loss: 0.1428
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9883 - loss: 0.0878 - val_accuracy: 0.9654 - val_loss: 0.1367
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9868 - loss: 0.0829 - val_accuracy: 0.9761 - val_loss: 0.1268
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 143ms/step - accuracy: 0.9885 - loss: 0.0789 - val_accuracy: 0.9707 - val_loss: 0.1300
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9825 - loss: 0.0803 - val_accuracy: 0.9734 - val_loss: 0.1107
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - accuracy: 0.9842 - loss: 0.0810 - val_accuracy: 0.9761 - val_loss: 0.0982
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 142ms/step - accuracy: 0.9869 - loss: 0.0710 - val_accuracy: 0.9681 - val_loss: 0.1120
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.9957 - loss: 0.0535 - val_accuracy: 0.9707 - val_loss: 0.1058
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.9947 - loss: 0.0500 - val_accuracy: 0.9707 - val_loss: 0.0957
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 145ms/step - accuracy: 0.9919 - loss: 0.0509 - val_accuracy: 0.9707 - val_loss: 0.1087
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.9936 - loss: 0.0480 - val_accuracy: 0.9681 - val_loss: 0.1028
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 154ms/step - accuracy: 0.9937 - loss: 0.0433 - val_accuracy: 0.9761 - val_loss: 0.1209
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.9973 - loss: 0.0404 - val_accuracy: 0.9734 - val_loss: 0.1181
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9957 - loss: 0.0409 - val_accuracy: 0.9761 - val_loss: 0.1037
# >>> Evaluating InceptionV3 on the Test data:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_626']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 114s 10s/step
# >>> Test Accuracy for InceptionV3: 97.63%.
# >>> Total execution time: 18 minutes and 17 seconds.
